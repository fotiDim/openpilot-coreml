# %%
# Convert h5 to SavedModel format
from tensorflow import keras

model = keras.models.load_model('supercombo.keras')

model.save('./supercombo', save_format="tf")
# Out:
# WARNING:tensorflow:No training configuration found in save file: the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:From /Users/fotidim/.local/share/virtualenvs/coremltools-bQWKWdM_/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1786: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: ./supercombo/assets

# %%
# Load the saved model
import tensorflow as tf

keras_model = tf.keras.models.load_model('./supercombo')

# get input, output node names for the TF graph from the Keras model
print(keras_model.inputs)
print(keras_model.input_shape) # [(None, 12, 128, 256), (None, 8), (None, 512)]

input_name = keras_model.inputs[0].name.split(':')[0]
keras_output_node_name = keras_model.outputs[0].name.split(':')[0]
graph_output_node_name = keras_output_node_name.split('/')[-1]
# Out:
# [<tf.Tensor 'vision_input_imgs_1:0' shape=(None, 12, 128, 256) dtype=float32>, <tf.Tensor 'desire_1:0' shape=(None, 8) dtype=float32>, <tf.Tensor 'rnn_state_1:0' shape=(None, 512) dtype=float32>]
# [(None, 12, 128, 256), (None, 8), (None, 512)]

# %%
import tfcoreml

model = tfcoreml.convert('./supercombo',
                         mlmodel_path='./supercombo.mlmodel',
                         input_name_shape_dict={'vision_input_imgs': (1, 12, 128, 256),
                                               'desire': (1, 8),
                                               'rnn_state': (1, 512)},
                         output_feature_names=[graph_output_node_name],
                         minimum_ios_deployment_target='13')
# Out:
# 0 assert nodes deleted
# 1382 nodes deleted
# 184 nodes deleted
# 0 nodes deleted
# [Op Fusion] fuse_bias_add() deleted 142 nodes.
# 2 identity nodes deleted
# 147 disconnected nodes deleted
# [Op Fusion] Fused 354 nodes into BatchNorms.
# [SSAConverter] Converting function main ...
# [SSAConverter] [1/344] Converting op type: 'Placeholder', name: 'vision_input_imgs', output_shape: (1, 12, 128, 256).
# [SSAConverter] [2/344] Converting op type: 'Placeholder', name: 'desire', output_shape: (1, 8).
# [SSAConverter] [3/344] Converting op type: 'Placeholder', name: 'rnn_state', output_shape: (1, 512).
# [SSAConverter] [4/344] Converting op type: 'Const', name: 'model_3/vision_permute/PartitionedCall/PartitionedCall/transpose/perm', output_shape: (4,).
# [SSAConverter] [5/344] Converting op type: 'Const', name: 'model_3/vision_flatten/PartitionedCall/PartitionedCall/Const', output_shape: (2,).
# [SSAConverter] [6/344] Converting op type: 'Const', name: 'model_3/vision_flatten_1/PartitionedCall/PartitionedCall/Const', output_shape: (2,).
# [SSAConverter] [7/344] Converting op type: 'Const', name: 'model_3/vision_batch_normalization_7/StatefulPartitionedCall/StatefulPartitionedCall/batchnorm/mul', output_shape: (256,).
# [SSAConverter] [8/344] Converting op type: 'Const', name: 'model_3/vision_batch_normalization_7/StatefulPartitionedCall/StatefulPartitionedCall/batchnorm/sub', output_shape: (256,).
# [SSAConverter] [9/344] Converting op type: 'Const', name: 'model_3/vision_vision_features/PartitionedCall/PartitionedCall/concat/axis'.
# [SSAConverter] [10/344] Converting op type: 'Const', name: 'model_3/proc_features/PartitionedCall/PartitionedCall/concat/axis'.
# [SSAConverter] [11/344] Converting op type: 'MatMul', name: 'model_3/snpe_desire_pleaser/StatefulPartitionedCall/StatefulPartitionedCall/MatMul', output_shape: (1, 8).
# [SSAConverter] [12/344] Converting op type: 'MatMul', name: 'model_3/rnn_rz/StatefulPartitionedCall/StatefulPartitionedCall/MatMul', output_shape: (1, 512).
# [SSAConverter] [13/344] Converting op type: 'MatMul', name: 'model_3/snpe_pleaser/StatefulPartitionedCall/StatefulPartitionedCall/MatMul', output_shape: (1, 512).
# [SSAConverter] [14/344] Converting op type: 'MatMul', name: 'model_3/rnn_rr/StatefulPartitionedCall/StatefulPartitionedCall/MatMul', output_shape: (1, 512).
# [SSAConverter] [15/344] Converting op type: 'Transpose', name: 'model_3/vision_permute/PartitionedCall/PartitionedCall/transpose', output_shape: (1, 128, 256, 12).
# [SSAConverter] [16/344] Converting op type: 'MatMul', name: 'model_3/rnn_rh/StatefulPartitionedCall/StatefulPartitionedCall/MatMul', output_shape: (1, 512).
# [SSAConverter] [17/344] Converting op type: 'Transpose', name: 'model_3/vision_permute/PartitionedCall/PartitionedCall/transpose_to_nchw', output_shape: (1, 12, 128, 256).
# [SSAConverter] [18/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv2d/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 16, 128, 256).
# [SSAConverter] [19/344] Converting op type: 'Transpose', name: 'model_3/vision_conv2d/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D_to_nhwc', output_shape: (1, 128, 256, 16).
# [SSAConverter] [20/344] Converting op type: 'Elu', name: 'model_3/vision_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, 128, 256, 16).
# [SSAConverter] [21/344] Converting op type: 'Transpose', name: 'model_3/vision_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 16, 128, 256).
# [SSAConverter] [22/344] Converting op type: 'AvgPool', name: 'model_3/vision_average_pooling2d/PartitionedCall/PartitionedCall/AvgPool', output_shape: (1, 16, -1, -1).
# [SSAConverter] [23/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv2_block1_0_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 64, -1, -1).
# [SSAConverter] [24/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv2_block1_1_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 16, -1, -1).
# [SSAConverter] [25/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv2_block1_0_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 64, -1, -1).
# [SSAConverter] [26/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv2_block1_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 16, -1, -1).
# [SSAConverter] [27/344] Converting op type: 'Transpose', name: 'model_3/vision_conv2_block1_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 16).
# [SSAConverter] [28/344] Converting op type: 'Elu', name: 'model_3/vision_conv2_block1_1_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 16).
# [SSAConverter] [29/344] Converting op type: 'Transpose', name: 'model_3/vision_conv2_block1_1_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 16, -1, -1).
# [SSAConverter] [30/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv2_block1_2_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 16, -1, -1).
# [SSAConverter] [31/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv2_block1_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 16, -1, -1).
# [SSAConverter] [32/344] Converting op type: 'Transpose', name: 'model_3/vision_conv2_block1_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 16).
# [SSAConverter] [33/344] Converting op type: 'Elu', name: 'model_3/vision_conv2_block1_2_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 16).
# [SSAConverter] [34/344] Converting op type: 'Transpose', name: 'model_3/vision_conv2_block1_2_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 16, -1, -1).
# [SSAConverter] [35/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv2_block1_3_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 64, -1, -1).
# [SSAConverter] [36/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv2_block1_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 64, -1, -1).
# [SSAConverter] [37/344] Converting op type: 'AddV2', name: 'model_3/vision_conv2_block1_add/PartitionedCall/PartitionedCall/add', output_shape: (1, 64, -1, -1).
# [SSAConverter] [38/344] Converting op type: 'Transpose', name: 'model_3/vision_conv2_block1_add/PartitionedCall/PartitionedCall/add_to_nhwc', output_shape: (1, -1, -1, 64).
# [SSAConverter] [39/344] Converting op type: 'Elu', name: 'model_3/vision_conv2_block1_elu_out/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 64).
# [SSAConverter] [40/344] Converting op type: 'Transpose', name: 'model_3/vision_conv2_block1_elu_out/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 64, -1, -1).
# [SSAConverter] [41/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv2_block2_1_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 16, -1, -1).
# [SSAConverter] [42/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv2_block2_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 16, -1, -1).
# [SSAConverter] [43/344] Converting op type: 'Transpose', name: 'model_3/vision_conv2_block2_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 16).
# [SSAConverter] [44/344] Converting op type: 'Elu', name: 'model_3/vision_conv2_block2_1_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 16).
# [SSAConverter] [45/344] Converting op type: 'Transpose', name: 'model_3/vision_conv2_block2_1_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 16, -1, -1).
# [SSAConverter] [46/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv2_block2_2_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 16, -1, -1).
# [SSAConverter] [47/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv2_block2_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 16, -1, -1).
# [SSAConverter] [48/344] Converting op type: 'Transpose', name: 'model_3/vision_conv2_block2_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 16).
# [SSAConverter] [49/344] Converting op type: 'Elu', name: 'model_3/vision_conv2_block2_2_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 16).
# [SSAConverter] [50/344] Converting op type: 'Transpose', name: 'model_3/vision_conv2_block2_2_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 16, -1, -1).
# [SSAConverter] [51/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv2_block2_3_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 64, -1, -1).
# [SSAConverter] [52/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv2_block2_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 64, -1, -1).
# [SSAConverter] [53/344] Converting op type: 'Transpose', name: 'model_3/vision_conv2_block2_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 64).
# [SSAConverter] [54/344] Converting op type: 'AddV2', name: 'model_3/vision_conv2_block2_add/PartitionedCall/PartitionedCall/add', output_shape: (1, -1, -1, 64).
# [SSAConverter] [55/344] Converting op type: 'Elu', name: 'model_3/vision_conv2_block2_elu_out/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 64).
# [SSAConverter] [56/344] Converting op type: 'Transpose', name: 'model_3/vision_conv2_block2_elu_out/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 64, -1, -1).
# [SSAConverter] [57/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv2_block3_1_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 16, -1, -1).
# [SSAConverter] [58/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv2_block3_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 16, -1, -1).
# [SSAConverter] [59/344] Converting op type: 'Transpose', name: 'model_3/vision_conv2_block3_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 16).
# [SSAConverter] [60/344] Converting op type: 'Elu', name: 'model_3/vision_conv2_block3_1_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 16).
# [SSAConverter] [61/344] Converting op type: 'Transpose', name: 'model_3/vision_conv2_block3_1_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 16, -1, -1).
# [SSAConverter] [62/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv2_block3_2_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 16, -1, -1).
# [SSAConverter] [63/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv2_block3_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 16, -1, -1).
# [SSAConverter] [64/344] Converting op type: 'Transpose', name: 'model_3/vision_conv2_block3_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 16).
# [SSAConverter] [65/344] Converting op type: 'Elu', name: 'model_3/vision_conv2_block3_2_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 16).
# [SSAConverter] [66/344] Converting op type: 'Transpose', name: 'model_3/vision_conv2_block3_2_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 16, -1, -1).
# [SSAConverter] [67/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv2_block3_3_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 64, -1, -1).
# [SSAConverter] [68/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv2_block3_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 64, -1, -1).
# [SSAConverter] [69/344] Converting op type: 'Transpose', name: 'model_3/vision_conv2_block3_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 64).
# [SSAConverter] [70/344] Converting op type: 'AddV2', name: 'model_3/vision_conv2_block3_add/PartitionedCall/PartitionedCall/add', output_shape: (1, -1, -1, 64).
# [SSAConverter] [71/344] Converting op type: 'Elu', name: 'model_3/vision_conv2_block3_elu_out/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 64).
# [SSAConverter] [72/344] Converting op type: 'Transpose', name: 'model_3/vision_conv2_block3_elu_out/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 64, -1, -1).
# [SSAConverter] [73/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv3_block1_0_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 128, -1, -1).
# [SSAConverter] [74/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv3_block1_1_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 32, -1, -1).
# [SSAConverter] [75/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv3_block1_0_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 128, -1, -1).
# [SSAConverter] [76/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv3_block1_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 32, -1, -1).
# [SSAConverter] [77/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block1_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 32).
# [SSAConverter] [78/344] Converting op type: 'Elu', name: 'model_3/vision_conv3_block1_1_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 32).
# [SSAConverter] [79/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block1_1_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 32, -1, -1).
# [SSAConverter] [80/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv3_block1_2_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 32, -1, -1).
# [SSAConverter] [81/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv3_block1_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 32, -1, -1).
# [SSAConverter] [82/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block1_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 32).
# [SSAConverter] [83/344] Converting op type: 'Elu', name: 'model_3/vision_conv3_block1_2_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 32).
# [SSAConverter] [84/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block1_2_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 32, -1, -1).
# [SSAConverter] [85/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv3_block1_3_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 128, -1, -1).
# [SSAConverter] [86/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv3_block1_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 128, -1, -1).
# [SSAConverter] [87/344] Converting op type: 'AddV2', name: 'model_3/vision_conv3_block1_add/PartitionedCall/PartitionedCall/add', output_shape: (1, 128, -1, -1).
# [SSAConverter] [88/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block1_add/PartitionedCall/PartitionedCall/add_to_nhwc', output_shape: (1, -1, -1, 128).
# [SSAConverter] [89/344] Converting op type: 'Elu', name: 'model_3/vision_conv3_block1_elu_out/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 128).
# [SSAConverter] [90/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block1_elu_out/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 128, -1, -1).
# [SSAConverter] [91/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv3_block2_1_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 32, -1, -1).
# [SSAConverter] [92/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv3_block2_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 32, -1, -1).
# [SSAConverter] [93/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block2_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 32).
# [SSAConverter] [94/344] Converting op type: 'Elu', name: 'model_3/vision_conv3_block2_1_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 32).
# [SSAConverter] [95/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block2_1_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 32, -1, -1).
# [SSAConverter] [96/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv3_block2_2_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 32, -1, -1).
# [SSAConverter] [97/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv3_block2_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 32, -1, -1).
# [SSAConverter] [98/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block2_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 32).
# [SSAConverter] [99/344] Converting op type: 'Elu', name: 'model_3/vision_conv3_block2_2_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 32).
# [SSAConverter] [100/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block2_2_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 32, -1, -1).
# [SSAConverter] [101/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv3_block2_3_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 128, -1, -1).
# [SSAConverter] [102/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv3_block2_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 128, -1, -1).
# [SSAConverter] [103/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block2_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 128).
# [SSAConverter] [104/344] Converting op type: 'AddV2', name: 'model_3/vision_conv3_block2_add/PartitionedCall/PartitionedCall/add', output_shape: (1, -1, -1, 128).
# [SSAConverter] [105/344] Converting op type: 'Elu', name: 'model_3/vision_conv3_block2_elu_out/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 128).
# [SSAConverter] [106/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block2_elu_out/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 128, -1, -1).
# [SSAConverter] [107/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv3_block3_1_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 32, -1, -1).
# [SSAConverter] [108/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv3_block3_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 32, -1, -1).
# [SSAConverter] [109/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block3_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 32).
# [SSAConverter] [110/344] Converting op type: 'Elu', name: 'model_3/vision_conv3_block3_1_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 32).
# [SSAConverter] [111/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block3_1_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 32, -1, -1).
# [SSAConverter] [112/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv3_block3_2_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 32, -1, -1).
# [SSAConverter] [113/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv3_block3_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 32, -1, -1).
# [SSAConverter] [114/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block3_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 32).
# [SSAConverter] [115/344] Converting op type: 'Elu', name: 'model_3/vision_conv3_block3_2_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 32).
# [SSAConverter] [116/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block3_2_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 32, -1, -1).
# [SSAConverter] [117/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv3_block3_3_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 128, -1, -1).
# [SSAConverter] [118/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv3_block3_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 128, -1, -1).
# [SSAConverter] [119/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block3_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 128).
# [SSAConverter] [120/344] Converting op type: 'AddV2', name: 'model_3/vision_conv3_block3_add/PartitionedCall/PartitionedCall/add', output_shape: (1, -1, -1, 128).
# [SSAConverter] [121/344] Converting op type: 'Elu', name: 'model_3/vision_conv3_block3_elu_out/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 128).
# [SSAConverter] [122/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block3_elu_out/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 128, -1, -1).
# [SSAConverter] [123/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv3_block4_1_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 32, -1, -1).
# [SSAConverter] [124/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv3_block4_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 32, -1, -1).
# [SSAConverter] [125/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block4_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 32).
# [SSAConverter] [126/344] Converting op type: 'Elu', name: 'model_3/vision_conv3_block4_1_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 32).
# [SSAConverter] [127/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block4_1_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 32, -1, -1).
# [SSAConverter] [128/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv3_block4_2_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 32, -1, -1).
# [SSAConverter] [129/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv3_block4_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 32, -1, -1).
# [SSAConverter] [130/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block4_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 32).
# [SSAConverter] [131/344] Converting op type: 'Elu', name: 'model_3/vision_conv3_block4_2_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 32).
# [SSAConverter] [132/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block4_2_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 32, -1, -1).
# [SSAConverter] [133/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv3_block4_3_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 128, -1, -1).
# [SSAConverter] [134/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv3_block4_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 128, -1, -1).
# [SSAConverter] [135/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block4_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 128).
# [SSAConverter] [136/344] Converting op type: 'AddV2', name: 'model_3/vision_conv3_block4_add/PartitionedCall/PartitionedCall/add', output_shape: (1, -1, -1, 128).
# [SSAConverter] [137/344] Converting op type: 'Elu', name: 'model_3/vision_conv3_block4_elu_out/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 128).
# [SSAConverter] [138/344] Converting op type: 'Transpose', name: 'model_3/vision_conv3_block4_elu_out/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 128, -1, -1).
# [SSAConverter] [139/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv4_block1_0_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 192, -1, -1).
# [SSAConverter] [140/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv4_block1_1_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 48, -1, -1).
# [SSAConverter] [141/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv4_block1_0_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 192, -1, -1).
# [SSAConverter] [142/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv4_block1_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 48, -1, -1).
# [SSAConverter] [143/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block1_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 48).
# [SSAConverter] [144/344] Converting op type: 'Elu', name: 'model_3/vision_conv4_block1_1_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 48).
# [SSAConverter] [145/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block1_1_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 48, -1, -1).
# [SSAConverter] [146/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv4_block1_2_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 48, -1, -1).
# [SSAConverter] [147/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv4_block1_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 48, -1, -1).
# [SSAConverter] [148/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block1_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 48).
# [SSAConverter] [149/344] Converting op type: 'Elu', name: 'model_3/vision_conv4_block1_2_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 48).
# [SSAConverter] [150/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block1_2_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 48, -1, -1).
# [SSAConverter] [151/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv4_block1_3_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 192, -1, -1).
# [SSAConverter] [152/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv4_block1_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 192, -1, -1).
# [SSAConverter] [153/344] Converting op type: 'AddV2', name: 'model_3/vision_conv4_block1_add/PartitionedCall/PartitionedCall/add', output_shape: (1, 192, -1, -1).
# [SSAConverter] [154/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block1_add/PartitionedCall/PartitionedCall/add_to_nhwc', output_shape: (1, -1, -1, 192).
# [SSAConverter] [155/344] Converting op type: 'Elu', name: 'model_3/vision_conv4_block1_elu_out/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 192).
# [SSAConverter] [156/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block1_elu_out/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 192, -1, -1).
# [SSAConverter] [157/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv4_block2_1_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 48, -1, -1).
# [SSAConverter] [158/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv4_block2_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 48, -1, -1).
# [SSAConverter] [159/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block2_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 48).
# [SSAConverter] [160/344] Converting op type: 'Elu', name: 'model_3/vision_conv4_block2_1_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 48).
# [SSAConverter] [161/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block2_1_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 48, -1, -1).
# [SSAConverter] [162/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv4_block2_2_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 48, -1, -1).
# [SSAConverter] [163/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv4_block2_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 48, -1, -1).
# [SSAConverter] [164/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block2_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 48).
# [SSAConverter] [165/344] Converting op type: 'Elu', name: 'model_3/vision_conv4_block2_2_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 48).
# [SSAConverter] [166/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block2_2_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 48, -1, -1).
# [SSAConverter] [167/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv4_block2_3_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 192, -1, -1).
# [SSAConverter] [168/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv4_block2_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 192, -1, -1).
# [SSAConverter] [169/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block2_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 192).
# [SSAConverter] [170/344] Converting op type: 'AddV2', name: 'model_3/vision_conv4_block2_add/PartitionedCall/PartitionedCall/add', output_shape: (1, -1, -1, 192).
# [SSAConverter] [171/344] Converting op type: 'Elu', name: 'model_3/vision_conv4_block2_elu_out/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 192).
# [SSAConverter] [172/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block2_elu_out/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 192, -1, -1).
# [SSAConverter] [173/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv4_block3_1_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 48, -1, -1).
# [SSAConverter] [174/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv4_block3_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 48, -1, -1).
# [SSAConverter] [175/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block3_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 48).
# [SSAConverter] [176/344] Converting op type: 'Elu', name: 'model_3/vision_conv4_block3_1_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 48).
# [SSAConverter] [177/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block3_1_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 48, -1, -1).
# [SSAConverter] [178/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv4_block3_2_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 48, -1, -1).
# [SSAConverter] [179/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv4_block3_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 48, -1, -1).
# [SSAConverter] [180/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block3_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 48).
# [SSAConverter] [181/344] Converting op type: 'Elu', name: 'model_3/vision_conv4_block3_2_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 48).
# [SSAConverter] [182/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block3_2_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 48, -1, -1).
# [SSAConverter] [183/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv4_block3_3_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 192, -1, -1).
# [SSAConverter] [184/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv4_block3_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 192, -1, -1).
# [SSAConverter] [185/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block3_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 192).
# [SSAConverter] [186/344] Converting op type: 'AddV2', name: 'model_3/vision_conv4_block3_add/PartitionedCall/PartitionedCall/add', output_shape: (1, -1, -1, 192).
# [SSAConverter] [187/344] Converting op type: 'Elu', name: 'model_3/vision_conv4_block3_elu_out/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 192).
# [SSAConverter] [188/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block3_elu_out/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 192, -1, -1).
# [SSAConverter] [189/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv4_block4_1_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 48, -1, -1).
# [SSAConverter] [190/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv4_block4_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 48, -1, -1).
# [SSAConverter] [191/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block4_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 48).
# [SSAConverter] [192/344] Converting op type: 'Elu', name: 'model_3/vision_conv4_block4_1_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 48).
# [SSAConverter] [193/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block4_1_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 48, -1, -1).
# [SSAConverter] [194/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv4_block4_2_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 48, -1, -1).
# [SSAConverter] [195/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv4_block4_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 48, -1, -1).
# [SSAConverter] [196/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block4_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 48).
# [SSAConverter] [197/344] Converting op type: 'Elu', name: 'model_3/vision_conv4_block4_2_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 48).
# [SSAConverter] [198/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block4_2_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 48, -1, -1).
# [SSAConverter] [199/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv4_block4_3_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 192, -1, -1).
# [SSAConverter] [200/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv4_block4_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 192, -1, -1).
# [SSAConverter] [201/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block4_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 192).
# [SSAConverter] [202/344] Converting op type: 'AddV2', name: 'model_3/vision_conv4_block4_add/PartitionedCall/PartitionedCall/add', output_shape: (1, -1, -1, 192).
# [SSAConverter] [203/344] Converting op type: 'Elu', name: 'model_3/vision_conv4_block4_elu_out/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 192).
# [SSAConverter] [204/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block4_elu_out/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 192, -1, -1).
# [SSAConverter] [205/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv4_block5_1_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 48, -1, -1).
# [SSAConverter] [206/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv4_block5_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 48, -1, -1).
# [SSAConverter] [207/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block5_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 48).
# [SSAConverter] [208/344] Converting op type: 'Elu', name: 'model_3/vision_conv4_block5_1_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 48).
# [SSAConverter] [209/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block5_1_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 48, -1, -1).
# [SSAConverter] [210/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv4_block5_2_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 48, -1, -1).
# [SSAConverter] [211/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv4_block5_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 48, -1, -1).
# [SSAConverter] [212/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block5_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 48).
# [SSAConverter] [213/344] Converting op type: 'Elu', name: 'model_3/vision_conv4_block5_2_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 48).
# [SSAConverter] [214/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block5_2_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 48, -1, -1).
# [SSAConverter] [215/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv4_block5_3_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 192, -1, -1).
# [SSAConverter] [216/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv4_block5_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 192, -1, -1).
# [SSAConverter] [217/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block5_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 192).
# [SSAConverter] [218/344] Converting op type: 'AddV2', name: 'model_3/vision_conv4_block5_add/PartitionedCall/PartitionedCall/add', output_shape: (1, -1, -1, 192).
# [SSAConverter] [219/344] Converting op type: 'Elu', name: 'model_3/vision_conv4_block5_elu_out/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 192).
# [SSAConverter] [220/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block5_elu_out/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 192, -1, -1).
# [SSAConverter] [221/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv4_block6_1_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 48, -1, -1).
# [SSAConverter] [222/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv4_block6_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 48, -1, -1).
# [SSAConverter] [223/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block6_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 48).
# [SSAConverter] [224/344] Converting op type: 'Elu', name: 'model_3/vision_conv4_block6_1_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 48).
# [SSAConverter] [225/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block6_1_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 48, -1, -1).
# [SSAConverter] [226/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv4_block6_2_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 48, -1, -1).
# [SSAConverter] [227/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv4_block6_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 48, -1, -1).
# [SSAConverter] [228/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block6_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 48).
# [SSAConverter] [229/344] Converting op type: 'Elu', name: 'model_3/vision_conv4_block6_2_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 48).
# [SSAConverter] [230/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block6_2_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 48, -1, -1).
# [SSAConverter] [231/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv4_block6_3_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 192, -1, -1).
# [SSAConverter] [232/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv4_block6_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 192, -1, -1).
# [SSAConverter] [233/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block6_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 192).
# [SSAConverter] [234/344] Converting op type: 'AddV2', name: 'model_3/vision_conv4_block6_add/PartitionedCall/PartitionedCall/add', output_shape: (1, -1, -1, 192).
# [SSAConverter] [235/344] Converting op type: 'Elu', name: 'model_3/vision_conv4_block6_elu_out/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 192).
# [SSAConverter] [236/344] Converting op type: 'Transpose', name: 'model_3/vision_conv4_block6_elu_out/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 192, -1, -1).
# [SSAConverter] [237/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv5_block1_0_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 256, -1, -1).
# [SSAConverter] [238/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv5_block1_1_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 64, -1, -1).
# [SSAConverter] [239/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv5_block1_0_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 256, -1, -1).
# [SSAConverter] [240/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv5_block1_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 64, -1, -1).
# [SSAConverter] [241/344] Converting op type: 'Transpose', name: 'model_3/vision_conv5_block1_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 64).
# [SSAConverter] [242/344] Converting op type: 'Elu', name: 'model_3/vision_conv5_block1_1_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 64).
# [SSAConverter] [243/344] Converting op type: 'Transpose', name: 'model_3/vision_conv5_block1_1_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 64, -1, -1).
# [SSAConverter] [244/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv5_block1_2_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 64, -1, -1).
# [SSAConverter] [245/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv5_block1_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 64, -1, -1).
# [SSAConverter] [246/344] Converting op type: 'Transpose', name: 'model_3/vision_conv5_block1_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 64).
# [SSAConverter] [247/344] Converting op type: 'Elu', name: 'model_3/vision_conv5_block1_2_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 64).
# [SSAConverter] [248/344] Converting op type: 'Transpose', name: 'model_3/vision_conv5_block1_2_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 64, -1, -1).
# [SSAConverter] [249/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv5_block1_3_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 256, -1, -1).
# [SSAConverter] [250/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv5_block1_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 256, -1, -1).
# [SSAConverter] [251/344] Converting op type: 'AddV2', name: 'model_3/vision_conv5_block1_add/PartitionedCall/PartitionedCall/add', output_shape: (1, 256, -1, -1).
# [SSAConverter] [252/344] Converting op type: 'Transpose', name: 'model_3/vision_conv5_block1_add/PartitionedCall/PartitionedCall/add_to_nhwc', output_shape: (1, -1, -1, 256).
# [SSAConverter] [253/344] Converting op type: 'Elu', name: 'model_3/vision_conv5_block1_elu_out/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 256).
# [SSAConverter] [254/344] Converting op type: 'Transpose', name: 'model_3/vision_conv5_block1_elu_out/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 256, -1, -1).
# [SSAConverter] [255/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv5_block2_1_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 64, -1, -1).
# [SSAConverter] [256/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv5_block2_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 64, -1, -1).
# [SSAConverter] [257/344] Converting op type: 'Transpose', name: 'model_3/vision_conv5_block2_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 64).
# [SSAConverter] [258/344] Converting op type: 'Elu', name: 'model_3/vision_conv5_block2_1_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 64).
# [SSAConverter] [259/344] Converting op type: 'Transpose', name: 'model_3/vision_conv5_block2_1_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 64, -1, -1).
# [SSAConverter] [260/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv5_block2_2_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 64, -1, -1).
# [SSAConverter] [261/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv5_block2_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 64, -1, -1).
# [SSAConverter] [262/344] Converting op type: 'Transpose', name: 'model_3/vision_conv5_block2_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 64).
# [SSAConverter] [263/344] Converting op type: 'Elu', name: 'model_3/vision_conv5_block2_2_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 64).
# [SSAConverter] [264/344] Converting op type: 'Transpose', name: 'model_3/vision_conv5_block2_2_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 64, -1, -1).
# [SSAConverter] [265/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv5_block2_3_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 256, -1, -1).
# [SSAConverter] [266/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv5_block2_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 256, -1, -1).
# [SSAConverter] [267/344] Converting op type: 'Transpose', name: 'model_3/vision_conv5_block2_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 256).
# [SSAConverter] [268/344] Converting op type: 'AddV2', name: 'model_3/vision_conv5_block2_add/PartitionedCall/PartitionedCall/add', output_shape: (1, -1, -1, 256).
# [SSAConverter] [269/344] Converting op type: 'Elu', name: 'model_3/vision_conv5_block2_elu_out/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 256).
# [SSAConverter] [270/344] Converting op type: 'Transpose', name: 'model_3/vision_conv5_block2_elu_out/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 256, -1, -1).
# [SSAConverter] [271/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv5_block3_1_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 64, -1, -1).
# [SSAConverter] [272/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv5_block3_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 64, -1, -1).
# [SSAConverter] [273/344] Converting op type: 'Transpose', name: 'model_3/vision_conv5_block3_1_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 64).
# [SSAConverter] [274/344] Converting op type: 'Elu', name: 'model_3/vision_conv5_block3_1_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 64).
# [SSAConverter] [275/344] Converting op type: 'Transpose', name: 'model_3/vision_conv5_block3_1_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 64, -1, -1).
# [SSAConverter] [276/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv5_block3_2_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 64, -1, -1).
# [SSAConverter] [277/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv5_block3_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 64, -1, -1).
# [SSAConverter] [278/344] Converting op type: 'Transpose', name: 'model_3/vision_conv5_block3_2_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 64).
# [SSAConverter] [279/344] Converting op type: 'Elu', name: 'model_3/vision_conv5_block3_2_elu/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 64).
# [SSAConverter] [280/344] Converting op type: 'Transpose', name: 'model_3/vision_conv5_block3_2_elu/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 64, -1, -1).
# [SSAConverter] [281/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv5_block3_3_conv/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 256, -1, -1).
# [SSAConverter] [282/344] Converting op type: 'BatchNorm', name: 'model_3/vision_conv5_block3_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 256, -1, -1).
# [SSAConverter] [283/344] Converting op type: 'Transpose', name: 'model_3/vision_conv5_block3_3_bn/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 256).
# [SSAConverter] [284/344] Converting op type: 'AddV2', name: 'model_3/vision_conv5_block3_add/PartitionedCall/PartitionedCall/add', output_shape: (1, -1, -1, 256).
# [SSAConverter] [285/344] Converting op type: 'Elu', name: 'model_3/vision_conv5_block3_elu_out/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 256).
# [SSAConverter] [286/344] Converting op type: 'Transpose', name: 'model_3/vision_conv5_block3_elu_out/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 256, -1, -1).
# [SSAConverter] [287/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv2d_1/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 4, -1, -1).
# [SSAConverter] [288/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv2d_2/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 96, -1, -1).
# [SSAConverter] [289/344] Converting op type: 'BatchNorm', name: 'model_3/vision_batch_normalization/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 4, -1, -1).
# [SSAConverter] [290/344] Converting op type: 'BatchNorm', name: 'model_3/vision_batch_normalization_1/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 96, -1, -1).
# [SSAConverter] [291/344] Converting op type: 'Transpose', name: 'model_3/vision_batch_normalization/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 4).
# [SSAConverter] [292/344] Converting op type: 'Transpose', name: 'model_3/vision_batch_normalization_1/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 96).
# [SSAConverter] [293/344] Converting op type: 'Elu', name: 'model_3/vision_elu_1/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 4).
# [SSAConverter] [294/344] Converting op type: 'Elu', name: 'model_3/vision_elu_2/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 96).
# [SSAConverter] [295/344] Converting op type: 'Reshape', name: 'model_3/vision_flatten/PartitionedCall/PartitionedCall/Reshape', output_shape: (1, 512).
# [SSAConverter] [296/344] Converting op type: 'Transpose', name: 'model_3/vision_elu_2/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 96, -1, -1).
# [SSAConverter] [297/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv2d_3/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 96, -1, -1).
# [SSAConverter] [298/344] Converting op type: 'BatchNorm', name: 'model_3/vision_batch_normalization_2/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 96, -1, -1).
# [SSAConverter] [299/344] Converting op type: 'Transpose', name: 'model_3/vision_batch_normalization_2/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 96).
# [SSAConverter] [300/344] Converting op type: 'Elu', name: 'model_3/vision_elu_3/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 96).
# [SSAConverter] [301/344] Converting op type: 'Transpose', name: 'model_3/vision_elu_3/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 96, -1, -1).
# [SSAConverter] [302/344] Converting op type: 'MaxPool', name: 'model_3/vision_max_pooling2d/PartitionedCall/PartitionedCall/MaxPool', output_shape: (1, 96, -1, -1).
# [SSAConverter] [303/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv2d_4/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 128, -1, -1).
# [SSAConverter] [304/344] Converting op type: 'BatchNorm', name: 'model_3/vision_batch_normalization_3/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 128, -1, -1).
# [SSAConverter] [305/344] Converting op type: 'Transpose', name: 'model_3/vision_batch_normalization_3/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 128).
# [SSAConverter] [306/344] Converting op type: 'Elu', name: 'model_3/vision_elu_4/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 128).
# [SSAConverter] [307/344] Converting op type: 'Transpose', name: 'model_3/vision_elu_4/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 128, -1, -1).
# [SSAConverter] [308/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv2d_5/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 128, -1, -1).
# [SSAConverter] [309/344] Converting op type: 'BatchNorm', name: 'model_3/vision_batch_normalization_4/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 128, -1, -1).
# [SSAConverter] [310/344] Converting op type: 'Transpose', name: 'model_3/vision_batch_normalization_4/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 128).
# [SSAConverter] [311/344] Converting op type: 'Elu', name: 'model_3/vision_elu_5/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 128).
# [SSAConverter] [312/344] Converting op type: 'Transpose', name: 'model_3/vision_elu_5/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 128, -1, -1).
# [SSAConverter] [313/344] Converting op type: 'MaxPool', name: 'model_3/vision_max_pooling2d_1/PartitionedCall/PartitionedCall/MaxPool', output_shape: (1, 128, -1, -1).
# [SSAConverter] [314/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv2d_6/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 192, -1, -1).
# [SSAConverter] [315/344] Converting op type: 'BatchNorm', name: 'model_3/vision_batch_normalization_5/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 192, -1, -1).
# [SSAConverter] [316/344] Converting op type: 'Transpose', name: 'model_3/vision_batch_normalization_5/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 192).
# [SSAConverter] [317/344] Converting op type: 'Elu', name: 'model_3/vision_elu_6/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 192).
# [SSAConverter] [318/344] Converting op type: 'Transpose', name: 'model_3/vision_elu_6/PartitionedCall/PartitionedCall/Elu_to_nchw', output_shape: (1, 192, -1, -1).
# [SSAConverter] [319/344] Converting op type: 'Conv2D', name: 'model_3/vision_conv2d_7/StatefulPartitionedCall/StatefulPartitionedCall/Conv2D', output_shape: (1, 192, -1, -1).
# [SSAConverter] [320/344] Converting op type: 'BatchNorm', name: 'model_3/vision_batch_normalization_6/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_batch_norm', output_shape: (1, 192, -1, -1).
# [SSAConverter] [321/344] Converting op type: 'Transpose', name: 'model_3/vision_batch_normalization_6/StatefulPartitionedCall/StatefulPartitionedCall/FusedBatchNormV3/Add_to_nhwc', output_shape: (1, -1, -1, 192).
# [SSAConverter] [322/344] Converting op type: 'Elu', name: 'model_3/vision_elu_7/PartitionedCall/PartitionedCall/Elu', output_shape: (1, -1, -1, 192).
# [SSAConverter] [323/344] Converting op type: 'Reshape', name: 'model_3/vision_flatten_1/PartitionedCall/PartitionedCall/Reshape', output_shape: (1, 1536).
# [SSAConverter] [324/344] Converting op type: 'MatMul', name: 'model_3/vision_dense/StatefulPartitionedCall/StatefulPartitionedCall/MatMul', output_shape: (1, 256).
# [SSAConverter] [325/344] Converting op type: 'Mul', name: 'model_3/vision_batch_normalization_7/StatefulPartitionedCall/StatefulPartitionedCall/batchnorm/mul_1', output_shape: (1, 256).
# [SSAConverter] [326/344] Converting op type: 'AddV2', name: 'model_3/vision_batch_normalization_7/StatefulPartitionedCall/StatefulPartitionedCall/batchnorm/add_1', output_shape: (1, 256).
# [SSAConverter] [327/344] Converting op type: 'Elu', name: 'model_3/vision_elu_8/PartitionedCall/PartitionedCall/Elu', output_shape: (1, 256).
# [SSAConverter] [328/344] Converting op type: 'ConcatV2', name: 'model_3/vision_vision_features/PartitionedCall/PartitionedCall/concat', output_shape: (1, 768).
# [SSAConverter] [329/344] Converting op type: 'ConcatV2', name: 'model_3/proc_features/PartitionedCall/PartitionedCall/concat', output_shape: (1, 776).
# [SSAConverter] [330/344] Converting op type: 'MatMul', name: 'model_3/pre_gru_dense/StatefulPartitionedCall/StatefulPartitionedCall/MatMul', output_shape: (1, 512).
# [SSAConverter] [331/344] Converting op type: 'MatMul', name: 'model_3/rnn_z/StatefulPartitionedCall/StatefulPartitionedCall/MatMul', output_shape: (1, 512).
# [SSAConverter] [332/344] Converting op type: 'MatMul', name: 'model_3/rnn_h/StatefulPartitionedCall/StatefulPartitionedCall/MatMul', output_shape: (1, 512).
# [SSAConverter] [333/344] Converting op type: 'MatMul', name: 'model_3/rnn_r/StatefulPartitionedCall/StatefulPartitionedCall/MatMul', output_shape: (1, 512).
# [SSAConverter] [334/344] Converting op type: 'AddV2', name: 'model_3/add/PartitionedCall/PartitionedCall/add', output_shape: (1, 512).
# [SSAConverter] [335/344] Converting op type: 'AddV2', name: 'model_3/add_1/PartitionedCall/PartitionedCall/add', output_shape: (1, 512).
# [SSAConverter] [336/344] Converting op type: 'Sigmoid', name: 'model_3/activation_1/PartitionedCall/PartitionedCall/Sigmoid', output_shape: (1, 512).
# [SSAConverter] [337/344] Converting op type: 'Sigmoid', name: 'model_3/activation/PartitionedCall/PartitionedCall/Sigmoid', output_shape: (1, 512).
# [SSAConverter] [338/344] Converting op type: 'Mul', name: 'model_3/multiply_1/PartitionedCall/PartitionedCall/mul', output_shape: (1, 512).
# [SSAConverter] [339/344] Converting op type: 'MatMul', name: 'model_3/one_minus/StatefulPartitionedCall/StatefulPartitionedCall/MatMul', output_shape: (1, 512).
# [SSAConverter] [340/344] Converting op type: 'Mul', name: 'model_3/multiply/PartitionedCall/PartitionedCall/mul', output_shape: (1, 512).
# [SSAConverter] [341/344] Converting op type: 'AddV2', name: 'model_3/add_2/PartitionedCall/PartitionedCall/add', output_shape: (1, 512).
# [SSAConverter] [342/344] Converting op type: 'Tanh', name: 'model_3/activation_2/PartitionedCall/PartitionedCall/Tanh', output_shape: (1, 512).
# [SSAConverter] [343/344] Converting op type: 'Mul', name: 'model_3/multiply_2/PartitionedCall/PartitionedCall/mul', output_shape: (1, 512).
# [SSAConverter] [344/344] Converting op type: 'AddV2', name: 'Identity', output_shape: (1, 512).
